# %% [markdown]
# # Predictive analysis on United States of America Gun violence Dataset involving Socioeconomic parameters

# %% [markdown]
# ## Abstract
# Gun Violence is a very serious issue faced by many countries around the world. It is very common to hear every day in the News media that “There has been a Shooting Incident” in the USA, even though the United States has 28th the highest rate of deaths related to gun violence in the world in 2017. The U.S. has seen a rise in gun-related violence, and it has the highest rate of murder by firearm among the developed nation. According to a study by CDC 58 percentage of American Adults experience gun-related violence and three million American children’s face gun violence every year.
# In this report, we will do a detailed analysis on the United states Gun violence data collected from 2013 to 2018 for better understanding how dangerous is the gun culture in America. A detailed inference on a few of the basic questions such as which age group, gender, state, the city is most affected by gun violence is answered. The focus of this analysis is to include an extra parameter such as population, per-capita and un-employment rate in each U.S. states to predict which state is most dangerous and safest from this gun violence. This inclusion of these socioeconomic data will give a clear picture of the seriousness of the Gun violence and answers importance of the included data. Apart from this prediction we also predict which month of the year, which day of the week is dangerous or safer. Prediction is done by making use of machine learning methods such as K means clustering and Hierarchical clustering. Risk score is generated by giving proper weightage to attribute to predict which month of the year, day of the week and which U.S. State is most safe and dangerous from Gun related violence.

# %% [markdown]
# ## Introduction
#
# A brief introduction of the History and current scenario of United States Gun violence and detailed outline on United States Population, Unemployment and Per-Capita income. This chapter also includes Motivation of the report and objectives that was achieved in this report.
#
# ### United States Gun Violence
#
# #### Prelude
#
# According to an article by renowned American Activist, writer and historian Roxanne Dunbar-Ortiz history of Gun culture and its origin in the wars against indigenous people. Article tells us about secret history about Second Amendment of United states constitution in 1791. [1] The United States, she writes, “was founded on conquered land, with capital in the form of slaves, hence the term chattel slavery. This was exceptional in the world and has remained exceptional. The capitalist firearms industry was among the first successful modern corporations. Gun proliferation and gun violence today are among its legacies.”. She argues that “understanding the second amendment is key to understand the gun culture in United States”. After independence from Britain the newly formed United States established the individual rights for having firearms so that independent militias and settlers to do dirty work of invading indigenous nations or “Taking land by force” from the indigenous communities. She has also disproved a myth like “right to bear arms” has to do with protecting right to hunt, she says that second amendment has nothing to with hunting. Gun industries has peddled its products to promote the Gun culture by supported ideologies like “Gun Rights”.
#
# #### Current Situation
#
# Gun culture has a deeper history roots back to American continental conquest, slavery, second amendment which gave right for arms and later as the leading military power in the world. U.S. is the world’s leading buyer and exporter of military weapons, there is a huge power of gun lobby to keep the weapons industry to be highly profitable in United States and keeping the ideology “Gun rights” possession of it is still alive.
# There are around 393 million in circulation in the United States that is approximately 120.5 guns for every 100 people [2]. Around 58% of adult experience the gun related violence and around 3 million children witness the gun violence each year according to CDC [3]. The people they died from accident shooting are three times to have firearms in their home than in the controlled environment. Most of the death related to children are due to playing with preloaded guns in absence of their parents. Suicide rates are higher with the higher rates of gun ownership. Reason of Suicide are related to poverty, urbanization, unemployment, mental illness and alcohol or drug abuse. Assault style weapons are responsible for minority of the gun incidents in U.S., but it is the weapon of choice for the Mass shooting which can cause chaos and high fatalities. There is a high risk in the homicide eight-fold for women physically abusive relationship and this domestic violence are more likely to end up deadly with gun at home.
# In the current situation even though there is strong voice for “Prohibition of Guns” and some states have stricter laws for sale of firearms and possession of firearms. There is alarming increase in firearm homicide, firearm suicide and public mass shooting in United states, according to 2017 United states ranked 28th for the gun related violence and it is highest among the developed countries. Un-employment, poverty, mental illness, suicide rate, Gun availability are the main driving forces for increase in Gun culture in United states.
#
#
# ### United State Population, Un-Employment and Per-Capita Income.
#
# #### United State Population
#
# United states are well known for its diverse country with different ethnicities. It has high number of immigrants throughout the country’s history, with many people coming for a better life and opportunities. With this search for opportunities it known as “American Dream”, it has also become “melting pot” of different culture, nationalities and traditions. United states have third most population with 327.2 million in 2018 and its population is only expected to increase. It is estimated to see a steady growth over the next 40 years and by 2060 the population is estimated to be 400 million people [4].
# Many people are moving towards big cities for better life, few such state is California, Illinois, Texas and Florida. Its every come to hear Gun violence or a mass shooting in this state’s. Multiple factors such as large population, high number of immigrants each year, also with urbanization, high competition for jobs, Un-employment, poverty and on top of its easy access to firearms will only increase the Gun related violence.
#
# #### United State Un-Employment and Per-Capita Income.
#
# In a recent study by Daniel Kim, an associate professor of health science at Northeastern provides new insight into how socio-economic circumstances could be driving gun violence in the U.S. On average around 100 people are killed with guns every day. Between 2001 to 2013, gun violence incidents took more lives than the combined number of US people killed in war, AIDS, drug abuse and terrorism. This epidemic proportions are mainly due the roots in socio-economic causes, since there is high number of un-employment due to urbanization, less wages and high cost of living this has direct relation to the Gun violence in USA. After the several massing shooting incidents studies and investigation shows that many of it is due to the economic downtrend seen by the individual who caused the incidents.
#
# ### Motivation and Objectives
#
# #### Motivation
# Gun violence has reached alarming proportion as much as 100 people have died every day. Total victim count is more than the total lives lost due to wars, AIDS, drug abuse and terrorism put together. There has been a strong support for gun control in recent days, with 393 million gun in circulation and 120 gun for every 100 people it very difficult to see any reduction anytime soon, it is every important to understand the how Un-employment rate and per-capita income has influence on an individual or a family life, so it is important to understand these factors and find if there is any direct impact and facts related to the high Gun violence incident in certain U.S. States.
#
# #### Objectives of this Report
#
# Three main objectives of this reports are:
# •	To Clean and integrate the data from different sources
# •	To perform machine learning techniques on the data,
# •	To generate some statistical analysis and risk score ranking on Gun violence dataset involving socio-economic data.
#
# This report focusses on the relationship between the Gun Violence and Socio-Economic data, socio-economic data includes Un-employment and Per-capita income for each U.S. States. In this report there will be a 3D Geo-Visualization of the U.S. Gun violence Data from 2013 to 2018 using Deck-GL and Google Map API, an heatmap is generated to visualize which part of the U.S. Geographical region is highly or less affected by Gun violence and along with heatmap an hexagonal 3D projectile is generated to see the intensity of the Gun violence in certain areas.
#
# First, we will be focusing on the main dataset which includes the gun violence data from 2013 to 2018(Source – Kaggle), first and for most important part of this report is data cleaning, data modification that helps with our data analysis and prediction. After the data cleaning and data pre-processing some of the preliminary analysis on the main dataset has been done to answer questions such as which Age, which Gender and is there any correlation between the incidents and victims. Next most important part of the report is use of machine learning methods to answer which day of week, which month of year, which State and which City or county is most safe or dangerous from Gun related violence. Even a risk score ranking system is generated by giving proper weightage to the parameter to rank month, day and States to answer some of the questions.
#
# Just with the Gun violence data we cannot clearly say which State is more safe or dangerous, because it is very common to hear a mass shooting incident in California, Florida, Illinois and Texas but the most dangerous are not these states. To answer this question which state is more dangerous we are considering another dataset which includes Population, Un-Employment and Per-capita income. Finally, a risk score ranking system generated including this extra parameter to get more accurate prediction of which U.S. State is Dangerous and how the socio-economic factor plays a curial role in Gun culture in United States of America.

# %% [markdown]
# ## Data Collection and Overview
#
# One of the most important process before doing the data cleaning and data analysis is understanding the dataset which was collected. Understanding each of the attributes in the dataset is essential to come up with research questions for our analysis. We have made use of two dataset in our analysis.
#
# ### Data Collection
#
# #### What is Data Collection?
#
# Data collection is described as the “method of collecting and measuring information on variables of interest, in a recognized methodical approach that permits one to answer several questions, stated research queries, test hypotheses, and evaluate outcomes.”[4]
#
# #### Why Data Collection?
#
# Significance for Data collection meant for our analysis are as follows:
# 1.	It facilitates to answer few of our basic questions such which age group and which gender is highly affected by Gun violence.
# 2.	For our Geo-Visualization utilizing the longitude and latitude attributes in our dataset.
# 3.	For predicting which month of year and day of week is extremely dangerous and safe from Gun violence.
# 4.	Using number of people killed, people injured, number of fatal incidents and Gun involved attributes to generate Risk score in order to rank the U.S. States its risk for Gun violence. This risk rank is for our initial analysis only based on United States Gun Violence Dataset that was collected from Kaggle.
# 5.	Apart from work with United States Gun Violence Dataset to do initial analysis and preliminary Risk score ranking, we next include United States Population, Per-Capita and Un-Employment Dataset to determine if there is any relationship between extra included attributes and the Gun violence dataset attributes.
# 6.	Finally, with all the collected data attributes we will rank the U.S. state based the danger level for Gun Violence.
#
# #### Data Collection Source
#
# Source for our Data analysis and Geo-Visualization are follows:
# 1.	Source of the United States Gun Violence Dataset: https://www.kaggle.com/jameslko/gun-violence-data
# 2.	Source of the Dataset for 2018 Population Attribute: https://www.worldatlas.com/articles/us-states-by-population.html
# 3.	Source of the Dataset for Per-Capita Income and Un-Employment attributes: https://www.statista.com/
#
# ## Package import

# %%
# Python paackage importing for Analysis
import pandas as pd
import numpy as np
import datetime, calendar
import re 
import matplotlib.pyplot as plt
# %matplotlib inline
from pandas import DataFrame
import seaborn as sns
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from scipy.cluster.hierarchy import dendrogram, linkage
import datetime  
from datetime import date 
import calendar 
import matplotlib.mlab as mlab
import matplotlib as mp

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Data Preparation for Analysis
#
# Data preparation involves data collection, data cleaning and data modification of the Datasets. Dataset which was collected from different sources are stored as CSV file format. These datasets are imported for cleaning if any incorrect, mismatch or missing data is found, and cleaned data is modified if it useful for our analysis.
#
# #### Data Importing
#
# CSV (Comma-separated value) are the most used file format to store and transfer data. Using python reading, writing and manipulate data is a key skill for any data scientist and business analyst. Python Pandas library is used to read our Two datasets and manipulate the data frame using it.
# We are loading our two datasets for analysis.
#
# Our first dataset contains United States Gun Violence from 2013 to 2018 and second dataset has United States population, per-capita and Un-Employment data.
# Initial Description of the Datasets:
# 1.	United States Gun Violence Dataset details before data cleaning:
#
# United States Gun Violence Dataset consist of 239677 entries and around 29 attributes in our datasets. From our initial dataset description, we see that many of the attributes contains Null Values. It evident that we must do data cleaning before doing further data analysis and even some of the attributes are not required for our analysis. Some of the attributes can be used to extract new attributes that we will do in our data pre-processing.
# 2.	United States Population, Per-Capita and Un-Employment Dataset
#
# United States Population, Per-Capita and Un-Employment Dataset consists of 52 entries and 20 attributes. This dataset consists of Population, Per-Capita and Un-Employment details of U.S. States. In this dataset all the entries and attributes for our analysis related to finding relationship between Gun violence and this extra attributes in this dataset.
#
# #### Step Involved after Data Importing:
# 1.	First, we have to Data exploration or initial analysis of the entries and attributes in our dataset. This step has been done above.
# 2.	Next, we must do the Data cleaning and pre-processing so that the data is good to start with our Data analysis.

# %%
import pandas as pd
#Importing Dataset and storing it for Further Analysis
dataset1=pd.read_csv('gun_violence_data_2013_2018.csv')
dataset2=pd.read_csv('per_capita_data.csv')

# %%
dataset3=pd.read_csv('US_GunPermit_Edu_Suc.csv')

# %%
df_crime=dataset1
df_capita=dataset2
df_Gun_Edu=dataset3

# %% [markdown]
# ## Data Cleaning and modification
#
# ### Data Cleaning
#
# #### What is Data cleaning?
#
# Data that we have need to be cleaned for our analysis, this process of preparing data for data analysis by removing or modifying the incorrect, duplicate, irrelevant and improper data can be called as Data Cleaning. Data that we get mostly be unnecessary or not helpful they may result in an inaccurate result. Data cleaning is not only about removing data, but it is rather than finding a way to maximize the dataset accuracy without necessarily deleting information. This process includes more than removing data, such as correcting spelling, standardizing data and fixing mistakes such as duplicate, missing and empty values.
#
# #### Why Data cleaning?
#
# Data cleaning is the most important part is any data science related projects or analysis. This process results to the following:
# 1.	More accurate results.
# 2.	Less processing times.
# 3.	Results in less algorithm for analysis.
# 4.	Improves better understanding of models.
#
# #### Data cleaning and modification for our Analysis.
# First, we must do initial investigation on our Datasets before we do any deleting or modifying on our dataset. It is very important to do an investigation on our dataset so that we come to a concussion which attributes are very important for our analysis. Investigation involves for checking incorrect, missing and duplicate data in dataset.
# United States Gun Violence Dataset Cleaning.
#
# Following Observation are done from our Gun violence dataset description HeatMap:
#
# 1.	There are total 239676 entries and 29 attributes in our dataset.
# 2.	Since we know all the description of all our attributes in our dataset from Chapter 4 we can exclude attributes like “incident_id “, “address”, “source_url”, “incident_url”, ” incident_url_fields_missing”, “congressional_district”, ”incident_characteristics”,” participant_status”, ” participant_type”, ”sources”, “notes”, ” state_house_district” and ” state_senate_district”. These attributes may have fewer null values, but we are removing only because these attributes won’t provide necessary importance for our main Analysis objective. Most of these attributes are unique so there won’t be a correct answer for our analysis questions.
# 3.	Data cleaning process involves in deleting attributes if the attributes having more than 40 % Null values in our Dataset. Hence, we can remove “gun_stolen”, “gun_type”, “location_description”, “participant_age_group”, “participant_name” and “participant_relationship”.
# 4.	In our Data analysis we are not making use of “latitude” and “longitude” attributes. We are using these attributes only in our Geo-Visualization.
# 5.	We have checked for duplicate entries in Gun violence dataset.
#
# #### United States Gun Violence Dataset Modification.
#
# Gun violence Dataset is missing some very explicit attributes such as Number of Male and female involved in incident, Age of each participants, year of the incident, total individuals in each incident, which Month of year and which day of week for each incident. To extract or calculate these attributes we make use of existing attributes in our dataset.
#
# 1.	To calculating Male participant count from “participant_gender” attribute. We are extracting the “Male” string from this attribute and counting this and storing as a new attribute “male” in United States Gun Violence dataset
#
# 2.	To calculating Male participant count from “participant_gender” attribute. We are extracting the “Female” string from this attribute and counting this and storing as a new attribute “female” in United States Gun Violence dataset
#
# 3.	Extracting the Participants age Using regular expression from “participant_age” attribute and storing in as new attribute “Age” in United States Gun Violence dataset
#
# 4.	Creating new attribute “total_person” which stores the total count of participants who got killed and injured in United States Gun Violence dataset
#
# 5.	Removing or correcting some mismatches in “Male” and “Female” count in United States Gun Violence dataset
#
# 6.	Using datetime library which day of week, month of year and year are extracted from “date” attribute from United States Gun Violence dataset and stored in “day”, “month” and “year attributes.
#
# Note:
# •	United States Population, Per-Capita, Un-Employment Dataset doesn’t need any data cleaning or modification.

# %%
#Investigating Gun Shooting Incident Dataset
dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239677 entries, 0 to 239676
# Data columns (total 29 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   incident_id                  239677 non-null  int64
#  1   date                         239677 non-null  object
#  2   state                        239677 non-null  object
#  3   city_or_county               239677 non-null  object
#  4   address                      223180 non-null  object
#  5   n_killed                     239677 non-null  int64
#  6   n_injured                    239677 non-null  int64
#  7   incident_url                 239677 non-null  object
#  8   source_url                   239209 non-null  object
#  9   incident_url_fields_missing  239677 non-null  bool
#  10  congressional_district       227733 non-null  float64
#  11  gun_stolen                   140179 non-null  object
# ...

# %%
#Investigating Population, Per-Capita and Un-employment Dataset
dataset2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   State            51 non-null     object
#  1   Pop              51 non-null     float64
#  2   Per_Capita_2018  51 non-null     float64
#  3   Per_Capita_2017  51 non-null     float64
#  4   Per_Capita_2016  51 non-null     float64
#  5   Per_Capita_2015  51 non-null     float64
#  6   Per_Capita_2014  51 non-null     float64
#  7   Per_Capita_2013  51 non-null     float64
#  8   Une_Rate_2018    51 non-null     float64
#  9   Une_Rank_2018    51 non-null     float64
#  10  Une_Rate_2017    51 non-null     float64
#  11  Une_Rank_2017    51 non-null     float64
#  12  Une_Rate_2016    51 non-null     float64
#  13  Une_Rank_2016    51 non-null     float64
#  14  Une_Rate_2015    51 non-null     float64
#  15  Une_Rank_2015    51 non-null     float64
# ...

# %%
#Investigating Population, Gun-Permit, Education and Sucide Rate Dataset
dataset3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   State                           51 non-null     object
#  1   Permit                          51 non-null     object
#  2   High school graduate or higher  51 non-null     float64
#  3   Bachelors degree                51 non-null     float64
#  4   Advanced Degree                 51 non-null     float64
#  5   Average                         51 non-null     float64
#  6   Sucide Death Rate               51 non-null     float64
#  7   Population                      51 non-null     int64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 3.3+ KB

# %% [markdown]
# ## Investigating Dataset 1 for Null values for Data Cleaning

# %%
#Investigating Dataset 1 for Null values for Data Cleaning using heatmap
sns.heatmap(df_crime.isnull(), cbar=False,cmap="YlGnBu");
plt.title('HeatMap for Null value detection')
plt.savefig("data_cleaning_1.png")

# %%
# Find day from date column store as "day" field
def findDay(date): 
    year, month, day = (int(i) for i in date.split('-'))     
    born = datetime.date(year, month, day) 
    return born.strftime("%A") 
day=[]

for date in df_crime['date']:
    day.append(findDay(date))

df_crime['day']=day

# Find month from date column store as "month" field
def findMonth(date): 
    year, month, day = (int(i) for i in date.split('-'))     
    born = datetime.date(year, month, day) 
    return born.strftime("%B") 
month_value=[]
# Driver program 
for date in df_crime['date']:
   month_value.append(findMonth(date))

df_crime['month']=month_value

# Find year from date column store as "year" field
def findYear(date): 
    year, month, day = (int(i) for i in date.split('-'))     
    born = datetime.date(year, month, day) 
    return born.strftime("%Y") 
year_value=[]
# Driver program 
for date in df_crime['date']:
   year_value.append(findYear(date))

df_crime['year']=year_value

# %%
# Calculate total persons involed in gun shooting incident as store as "total_person" field
df_crime['total_person']=df_crime.n_killed + df_crime.n_injured

df_crime.loc[df_crime['total_person'] == 0,'participant_gender'] = np.nan

# %%
# Find Male participant count in incident and store as "male" filed
def findmalegender(gender):
    
    if type(gender)==str:
        count_value=gender.count("Male")
        if count_value == 0:
            return 0
        else:
            return count_value
    else:
        return 0
Male_value=[]


for gender in df_crime['participant_gender']:
   Male_value.append(findmalegender(gender))

df_crime['male']=Male_value

# Find Female participant count in incident and store as "Female" filed
def findfemalegender(gender):
    
    if type(gender)==str:
        count_value=gender.count("Female")
        if count_value == 0:
            return 0
        else:
            return count_value
    else:
        return 0
Female_value=[]


for gender in df_crime['participant_gender']:
   Female_value.append(findfemalegender(gender))

df_crime['Female']=Female_value

# Find  participant age in incident and store as "Age" filed
def findage(age):
    
    if type(age)==str:
        nested = re.findall('(?<=::)\d+',age)
    
        return list(map(int, nested))
            
age_value=[]


for age in df_crime['participant_age']:
   age_value.append(findage(age))

df_crime['Age']=age_value

# %%
# Removing some mismatch values in male and female count.
df_crime.male=(df_crime.male-(df_crime.male-df_crime.total_person))-df_crime.Female
df_crime.loc[df_crime['male'] < 0, 'male'] = 0
df_crime.loc[df_crime['male'] == 0, 'Female']=df_crime['total_person']

# %%
# Dropping unnessary field from dataset that we will not be using for analysis purpose.
df_crime.drop(labels=['incident_id','incident_url','latitude','longitude','gun_type','source_url','incident_url_fields_missing','location_description','congressional_district','notes','sources','state_house_district','participant_status','state_senate_district','participant_type','participant_relationship','participant_name','participant_gender','participant_age_group','participant_age','incident_characteristics','address','gun_stolen'],axis=1,inplace=True)

# %% [markdown]
# ### Final Data set after Data cleaning and Imputation
#
# After Data cleaning and data modification final dataset that will be used for answering data analytics Questions.

# %%
# Final dataset after our data cleaning and investigating for data discrepancy.
# Final Dataset1 after our data cleaning this is the main dataset that we will be focusing on.
df_crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239677 entries, 0 to 239676
# Data columns (total 13 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   date             239677 non-null  object
#  1   state            239677 non-null  object
#  2   city_or_county   239677 non-null  object
#  3   n_killed         239677 non-null  int64
#  4   n_injured        239677 non-null  int64
#  5   n_guns_involved  140226 non-null  float64
#  6   day              239677 non-null  object
#  7   month            239677 non-null  object
#  8   year             239677 non-null  object
#  9   total_person     239677 non-null  int64
#  10  male             239677 non-null  int64
#  11  Female           239677 non-null  int64
#  12  Age              147379 non-null  object
# dtypes: float64(1), int64(5), object(7)
# memory usage: 23.8+ MB

# %%
#Final dataset2 that we will be using for risk prediction analysis.
dataset2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   State            51 non-null     object
#  1   Pop              51 non-null     float64
#  2   Per_Capita_2018  51 non-null     float64
#  3   Per_Capita_2017  51 non-null     float64
#  4   Per_Capita_2016  51 non-null     float64
#  5   Per_Capita_2015  51 non-null     float64
#  6   Per_Capita_2014  51 non-null     float64
#  7   Per_Capita_2013  51 non-null     float64
#  8   Une_Rate_2018    51 non-null     float64
#  9   Une_Rank_2018    51 non-null     float64
#  10  Une_Rate_2017    51 non-null     float64
#  11  Une_Rank_2017    51 non-null     float64
#  12  Une_Rate_2016    51 non-null     float64
#  13  Une_Rank_2016    51 non-null     float64
#  14  Une_Rate_2015    51 non-null     float64
#  15  Une_Rank_2015    51 non-null     float64
# ...

# %%
#Final dataset3 that we will be using for risk prediction analysis.
dataset3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   State                           51 non-null     object
#  1   Permit                          51 non-null     object
#  2   High school graduate or higher  51 non-null     float64
#  3   Bachelors degree                51 non-null     float64
#  4   Advanced Degree                 51 non-null     float64
#  5   Average                         51 non-null     float64
#  6   Sucide Death Rate               51 non-null     float64
#  7   Population                      51 non-null     int64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 3.3+ KB

# %% [markdown]
# ## Data Analysis Interpretation
#
# ## Correlation between the Data

# %%
#To find any relationship or correlation between the fields in our main dataset(Dataset1)
corrMatrix = df_crime[['n_killed','n_injured','n_guns_involved','total_person','male','Female']].corr()
plt.figure(figsize=(6,4), dpi= 80)
sns.heatmap(corrMatrix, annot=True)
plt.title('Correlation between the fields')
plt.savefig("Corr_data_1.png")
plt.show()

# %% [markdown]
# ## What age group is most affected in USA Gun Shooting Data between 2013-2018?

# %%
#preliminary analysis of "Age" field in Dataset1
Age = []
def reemovNestings(l): 
    for i in l: 
        if type(i) == list: 
            reemovNestings(i) 
        else: 
            Age.append(i) 
  
# Driver code 
reemovNestings(df_crime.Age) 
df_Age = DataFrame(Age,columns=['Age'])
df_Age=df_Age.query('Age <=100')

fig, ax = plt.subplots(figsize=(10,6))

num_bins = 20
# the histogram of the "Age" filed.
ax.hist(df_Age['Age'], num_bins, facecolor='blue', alpha=0.5)
plt.xlabel('Age', fontsize = 12, weight = 'bold')
plt.ylabel('Count', fontsize = 12, weight = 'bold')
plt.title('What age group is most affected in USA Gun Shooting Data between 2013-2018?', fontsize = 12, weight = 'bold')

plt.savefig("Age_1.png");
plt.show()

# %%
round(df_Age['Age'].mean())
# Out:
# 29

# %%
round(df_Age['Age'].median())
# Out:
# 26

# %%
round(df_Age['Age'].mode())
# Out:
# 0    19.0
# dtype: float64

# %%
df_Age.describe()
# Out:
#                  Age
# count  218374.000000
# mean       29.470628
# std        13.089155
# min         0.000000
# 25%        20.000000
# 50%        26.000000
# 75%        35.000000
# max       100.000000

# %%
#Highest numebr of victims are aged 19 and count of it calculated
df_Age.query('Age==19').count()
# Out:
# Age    11535
# dtype: int64

# %%
#Count of victims less than 20 years Age
df_Age.query('Age<20').count()
# Out:
# Age    46446
# dtype: int64

# %%
#Count of victims more than or equal to age 20 and less than 40 years Age
df_Age.query('Age>=20 and Age<40').count()
# Out:
# Age    131795
# dtype: int64

# %%
#Count of victims greater than 40 years Age
df_Age.query('Age>=40').count()
# Out:
# Age    40133
# dtype: int64

# %% [markdown]
# ## Which USA State is the Dangerous based on the Gun shooting Data from 2013-2018?

# %%
#Group by "State" field and sum the values in each filed.
df_state=df_crime.groupby('state',as_index=False).sum()

# %%
df_state.sort_values('total_person',ascending=True,inplace=True)

# %%
# Colorize the graph based on likeability:
likeability_scores = np.array(df_state.total_person)
 
data_normalizer = mp.colors.Normalize()
color_map = mp.colors.LinearSegmentedColormap(
    "my_map",
    {
        "red": [(0, 1.0, 1.0),
                (1.0, .5, .5)],
        "green": [(0, 0.5, 0.5),
                  (1.0, 0, 0)],
        "blue": [(0, 0.50, 0.5),
                 (1.0, 0, 0)]
    }
)

plt.figure(figsize=(14,10), dpi= 80)
# Horizontal bar to dispaly the state wise victim count.
plt.barh(df_state.state, df_state.total_person, align='center',color=color_map(data_normalizer(likeability_scores)))


plt.ylabel('State', fontsize = 12, weight = 'bold')
plt.xlabel('Total persons involved in the incident', fontsize = 12, weight = 'bold')
plt.title('Which state has highest victims?', fontsize = 12, weight = 'bold')
plt.savefig("state_safe_1.png")
plt.show()
df_state.sort_values('total_person',ascending=False,inplace=True)

# %% [markdown]
# ## Which Gender is most affected over the years from 2013 to 2018?

# %%
#Group by "year" field and sum the values in each filed.
df_year=df_crime.groupby(['year'],as_index=False,observed= True).sum()
labels = [2013, 2014, 2015, 2016, 2017,2018]
men = df_year.male
women = df_year.Female
total = df_year.total_person

x = np.arange(len(labels))  # the label locations
width = 0.2  # the width of the bars

fig, ax = plt.subplots(figsize=(12,6))
# Bar chart for total victim count for each years from 2013 to 2018
rects1 = ax.bar(x + width/2, total, width, label='Total',color='orange')
# Bar chart for "Male" victim count for each years from 2013 to 2018
rects2 = ax.bar(x - width/2, men, width, label='Male',color='#54CFFB')
# Bar chart for "Female" victim count for each years from 2013 to 2018
rects3 = ax.bar(x - width/.7, women, width, label='Female',color='#ff77b4')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Year', fontsize = 12, weight = 'bold')
ax.set_ylabel('Total Count', fontsize = 12, weight = 'bold')
ax.set_title('Which Gender is most affected over the years from 2013 to 2018?', fontsize = 12, weight = 'bold')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

# Display labels for victim counts
def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 3, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)
autolabel(rects3)

fig.tight_layout()
plt.savefig("Gender_year_1.png") 
plt.show()

# %% [markdown]
# # Prediction based on Kmeans clustering
#
# ## Which USA states are highly dangerous and safe from Gun violance?

# %%
#Group by "State" field and sum the values in each filed.

df_state=df_crime.groupby('state',as_index=False)['date'].count()

df_state.drop(labels=['date'],axis=1,inplace=True)
#Spliting the victim count for each "state" and "year" and storing in new fields
x=df_crime.groupby(['state','year'],as_index=False).sum().query('year=="2013"')[['state','total_person']]
df_state=pd.merge(df_state,x, on='state',how = 'left')
df_state.rename(columns={'total_person': 'total_2013'}, inplace=True)
x=df_crime.groupby(['state','year'],as_index=False).sum().query('year=="2014"')[['state','total_person']]
df_state=pd.merge(df_state,x, on='state',how = 'left')
df_state.rename(columns={'total_person': 'total_2014'}, inplace=True)
x=df_crime.groupby(['state','year'],as_index=False).sum().query('year=="2015"')[['state','total_person']]
df_state=pd.merge(df_state,x, on='state',how = 'left')
df_state.rename(columns={'total_person': 'total_2015'}, inplace=True)
x=df_crime.groupby(['state','year'],as_index=False).sum().query('year=="2016"')[['state','total_person']]
df_state=pd.merge(df_state,x, on='state',how = 'left')
df_state.rename(columns={'total_person': 'total_2016'}, inplace=True)
x=df_crime.groupby(['state','year'],as_index=False).sum().query('year=="2017"')[['state','total_person']]
df_state=pd.merge(df_state,x, on='state',how = 'left')
df_state.rename(columns={'total_person': 'total_2017'}, inplace=True)
x=df_crime.groupby(['state','year'],as_index=False).sum().query('year=="2018"')[['state','total_person']]
df_state=pd.merge(df_state,x, on='state',how = 'left')
df_state.rename(columns={'total_person': 'total_2018'}, inplace=True)

#Spliting the incident count for each "state" and "year" and storing in new fields
x=df_crime.groupby(['state','year'],as_index=False).count().query('year=="2013"')[['state','total_person']]
df_state=pd.merge(df_state,x, on='state',how = 'left')
df_state.rename(columns={'total_person': 'incident_2013'}, inplace=True)
x=df_crime.groupby(['state','year'],as_index=False).count().query('year=="2014"')[['state','total_person']]
df_state=pd.merge(df_state,x, on='state',how = 'left')
df_state.rename(columns={'total_person': 'incident_2014'}, inplace=True)
x=df_crime.groupby(['state','year'],as_index=False).count().query('year=="2015"')[['state','total_person']]
df_state=pd.merge(df_state,x, on='state',how = 'left')
df_state.rename(columns={'total_person': 'incident_2015'}, inplace=True)
x=df_crime.groupby(['state','year'],as_index=False).count().query('year=="2016"')[['state','total_person']]
df_state=pd.merge(df_state,x, on='state',how = 'left')
df_state.rename(columns={'total_person': 'incident_2016'}, inplace=True)
x=df_crime.groupby(['state','year'],as_index=False).count().query('year=="2017"')[['state','total_person']]
df_state=pd.merge(df_state,x, on='state',how = 'left')
df_state.rename(columns={'total_person': 'incident_2017'}, inplace=True)
x=df_crime.groupby(['state','year'],as_index=False).count().query('year=="2018"')[['state','total_person']]
df_state=pd.merge(df_state,x, on='state',how = 'left')
df_state.rename(columns={'total_person': 'incident_2018'}, inplace=True)

df_state.fillna(0,inplace=True)

# %%
#Kmeans clustering for predicting dangerous "state" based on total victims and total incident for each years.
kmeans = KMeans(n_clusters=5)
predict= kmeans.fit_predict(df_state[['incident_2013','incident_2014','incident_2015','incident_2016','incident_2017','incident_2018','total_2013','total_2014','total_2015','total_2016','total_2017','total_2018']])
# storing cluster number after kmeans fit.
df_state['cluster']=predict
incidents=df_crime.groupby('state',as_index=False)['date'].count()

df_state['incidents']=incidents['date']
total_victim=df_crime.groupby('state',as_index=False).sum()

df_state['total_victim']=total_victim['total_person']

fig, ax = plt.subplots(figsize=(12,6))
#Scatter plot for incident vs victims and kmeans cluster number.
ax.scatter(df_state['incidents'],df_state['total_victim'], c=predict, s=50, cmap='viridis');
plt.xlabel('Number of Incidents', fontsize = 12, weight = 'bold')
plt.ylabel('Number of Victims', fontsize = 12, weight = 'bold')
plt.title('Kmeans clustering for which state is dangerous?', fontsize = 12, weight = 'bold')
plt.savefig("kmeans_state_1.png") 

plt.show()

# %%
df_state.groupby('cluster',as_index=False).count()['state']
# Out:
# 0    28
# 1     7
# 2     3
# 3     1
# 4    12
# Name: state, dtype: int64

# %%
# cluster 0
df_state.query('cluster==0')['state']
# Out:
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 11                  Hawaii
# 12                   Idaho
# 15                    Iowa
# 16                  Kansas
# 19                   Maine
# 23               Minnesota
# 26                 Montana
# 27                Nebraska
# 28                  Nevada
# 29           New Hampshire
# 31              New Mexico
# 34            North Dakota
# 36                Oklahoma
# 37                  Oregon
# 39            Rhode Island
# 41            South Dakota
# 44                    Utah
# 45                 Vermont
# 47              Washington
# 48           West Virginia
# 50                 Wyoming
# Name: state, dtype: object

# %%
# cluster 1
df_state.query('cluster==1')['state']
# Out:
# 10           Georgia
# 18         Louisiana
# 32          New York
# 33    North Carolina
# 35              Ohio
# 38      Pennsylvania
# 42         Tennessee
# Name: state, dtype: object

# %%
# cluster 2
df_state.query('cluster==2')['state']
# Out:
# 4     California
# 9        Florida
# 43         Texas
# Name: state, dtype: object

# %%
# cluster 3
df_state.query('cluster==3')['state']
# Out:
# 13    Illinois
# Name: state, dtype: object

# %%
# cluster 4
df_state.query('cluster==4')['state']
# Out:
# 0            Alabama
# 14           Indiana
# 17          Kentucky
# 20          Maryland
# 21     Massachusetts
# 22          Michigan
# 24       Mississippi
# 25          Missouri
# 30        New Jersey
# 40    South Carolina
# 46          Virginia
# 49         Wisconsin
# Name: state, dtype: object

# %%
df_state
# Out:
#                    state  total_2013  total_2014  total_2015  total_2016  \
# 0                Alabama        12.0         916         947        1249
# 1                 Alaska         0.0          78         154         191
# 2                Arizona        24.0         442         408         571
# 3               Arkansas         0.0         400         400         541
# 4             California       185.0        2927        2821        3161
# 5               Colorado        13.0         313         458         506
# 6            Connecticut        15.0         281         421         426
# 7               Delaware        13.0         231         264         229
# 8   District of Columbia        44.0         390         469         445
# 9                Florida        58.0        2336        2343        2847
# 10               Georgia        31.0        1339        1691        1405
# 11                Hawaii         0.0          21          39          51
# ...

# %% [markdown]
# ## Which USA Cities are Dangerous and safe from Gun violance?

# %%
#Group by "city_or_county" field and sum the values in each filed.
df_city=df_crime.groupby('city_or_county',as_index=False)['date'].count()

df_city.drop(labels=['date'],axis=1,inplace=True)
#Spliting the victim count for each "city_or_county" and "year" and storing in new fields
x=df_crime.groupby(['city_or_county','year'],as_index=False).sum().query('year=="2013"')[['city_or_county','total_person']]
df_city=pd.merge(df_city,x, on='city_or_county',how = 'left')
df_city.rename(columns={'total_person': 'total_2013'}, inplace=True)
x=df_crime.groupby(['city_or_county','year'],as_index=False).sum().query('year=="2014"')[['city_or_county','total_person']]
df_city=pd.merge(df_city,x, on='city_or_county',how = 'left')
df_city.rename(columns={'total_person': 'total_2014'}, inplace=True)
x=df_crime.groupby(['city_or_county','year'],as_index=False).sum().query('year=="2015"')[['city_or_county','total_person']]
df_city=pd.merge(df_city,x, on='city_or_county',how = 'left')
df_city.rename(columns={'total_person': 'total_2015'}, inplace=True)
x=df_crime.groupby(['city_or_county','year'],as_index=False).sum().query('year=="2016"')[['city_or_county','total_person']]
df_city=pd.merge(df_city,x, on='city_or_county',how = 'left')
df_city.rename(columns={'total_person': 'total_2016'}, inplace=True)
x=df_crime.groupby(['city_or_county','year'],as_index=False).sum().query('year=="2017"')[['city_or_county','total_person']]
df_city=pd.merge(df_city,x, on='city_or_county',how = 'left')
df_city.rename(columns={'total_person': 'total_2017'}, inplace=True)
x=df_crime.groupby(['city_or_county','year'],as_index=False).sum().query('year=="2018"')[['city_or_county','total_person']]
df_city=pd.merge(df_city,x, on='city_or_county',how = 'left')
df_city.rename(columns={'total_person': 'total_2018'}, inplace=True)

#Spliting the incident count for each "city_or_county" and "year" and storing in new fields
x=df_crime.groupby(['city_or_county','year'],as_index=False).count().query('year=="2013"')[['city_or_county','total_person']]
df_city=pd.merge(df_city,x, on='city_or_county',how = 'left')
df_city.rename(columns={'total_person': 'incident_2013'}, inplace=True)
x=df_crime.groupby(['city_or_county','year'],as_index=False).count().query('year=="2014"')[['city_or_county','total_person']]
df_city=pd.merge(df_city,x, on='city_or_county',how = 'left')
df_city.rename(columns={'total_person': 'incident_2014'}, inplace=True)
x=df_crime.groupby(['city_or_county','year'],as_index=False).count().query('year=="2015"')[['city_or_county','total_person']]
df_city=pd.merge(df_city,x, on='city_or_county',how = 'left')
df_city.rename(columns={'total_person': 'incident_2015'}, inplace=True)
x=df_crime.groupby(['city_or_county','year'],as_index=False).count().query('year=="2016"')[['city_or_county','total_person']]
df_city=pd.merge(df_city,x, on='city_or_county',how = 'left')
df_city.rename(columns={'total_person': 'incident_2016'}, inplace=True)
x=df_crime.groupby(['city_or_county','year'],as_index=False).count().query('year=="2017"')[['city_or_county','total_person']]
df_city=pd.merge(df_city,x, on='city_or_county',how = 'left')
df_city.rename(columns={'total_person': 'incident_2017'}, inplace=True)
x=df_crime.groupby(['city_or_county','year'],as_index=False).count().query('year=="2018"')[['city_or_county','total_person']]
df_city=pd.merge(df_city,x, on='city_or_county',how = 'left')
df_city.rename(columns={'total_person': 'incident_2018'}, inplace=True)

df_city.fillna(0,inplace=True)

# %%
#Kmeans clustering for predicting dangerous "city_or_county" based on total victims and total incident for each years.
kmeans = KMeans(n_clusters=3)
predict= kmeans.fit_predict(df_city[['incident_2013','incident_2014','incident_2015','incident_2016','incident_2017','incident_2018','total_2013','total_2014','total_2015','total_2016','total_2017','total_2018']])
# storing cluster number after kmeans fit.
df_city['cluster']=predict
incidents=df_crime.groupby('city_or_county',as_index=False)['date'].count()

df_city['incidents']=incidents['date']
total_victim=df_crime.groupby('city_or_county',as_index=False).sum()

df_city['total_victim']=total_victim['total_person']
fig, ax = plt.subplots(figsize=(12,6))

#Scatter plot for incident vs victims and kmeans cluster number.
ax.scatter(df_city['incidents'],df_city['total_victim'] , c=predict, s=20, cmap='viridis')
plt.xlabel('Number of Incidents', fontsize = 12, weight = 'bold')
plt.ylabel('Number of Victims', fontsize = 12, weight = 'bold')
plt.title('Kmeans clustering for which city is dangerous?', fontsize = 12, weight = 'bold')
plt.savefig("kmeans_city_1.png") 
plt.show()

# %%
df_city.groupby('cluster').count()['city_or_county']
# Out:
# cluster
# 0    12842
# 1        1
# 2       55
# Name: city_or_county, dtype: int64

# %%
# cluster 1
#Most dangerous city or county in USA
df_city.query('cluster==1')
# Out:
#      city_or_county  total_2013  total_2014  total_2015  total_2016  \
# 2019        Chicago        77.0      2307.0      2771.0      3553.0
#
#       total_2017  total_2018  incident_2013  incident_2014  incident_2015  \
# 2019      3304.0       519.0           15.0         2042.0         2369.0
#
#       incident_2016  incident_2017  incident_2018  cluster  incidents  \
# 2019         3075.0         2812.0          501.0        1      10814
#
#       total_victim
# 2019         12531

# %%
# cluster 2
#Second and third dangerous city or county in USA with highest victim
df_city.query('cluster==2').sort_values(['total_victim'],ascending=False).head(2)
# Out:
#      city_or_county  total_2013  total_2014  total_2015  total_2016  \
# 530       Baltimore        21.0       614.0       877.0       846.0
# 9018   Philadelphia        29.0      1030.0       619.0       712.0
#
#       total_2017  total_2018  incident_2013  incident_2014  incident_2015  \
# 530        955.0       169.0            5.0          760.0          911.0
# 9018       683.0       154.0            9.0         1049.0          535.0
#
#       incident_2016  incident_2017  incident_2018  cluster  incidents  \
# 530           919.0         1113.0          235.0        2       3943
# 9018          659.0          581.0          130.0        2       2963
#
#       total_victim
# 530           3482
# 9018          3227

# %%
# cluster 2
#Second and third dangerous city or county in USA with highest incident
df_city.query('cluster==2').sort_values(['incidents'],ascending=False).head(2)
# Out:
#       city_or_county  total_2013  total_2014  total_2015  total_2016  \
# 530        Baltimore        21.0       614.0       877.0       846.0
# 12154     Washington        30.0       400.0       480.0       455.0
#
#        total_2017  total_2018  incident_2013  incident_2014  incident_2015  \
# 530         955.0       169.0            5.0          760.0          911.0
# 12154       453.0        89.0            5.0          850.0          553.0
#
#        incident_2016  incident_2017  incident_2018  cluster  incidents  \
# 530            919.0         1113.0          235.0        2       3943
# 12154          521.0         1171.0          179.0        2       3279
#
#        total_victim
# 530            3482
# 12154          1907

# %% [markdown]
# # Prediction based on linkage clustering
#
# ## Which Day of week has high chances of Gun violance?

# %%
#Group by "Day" field and sum the values in each filed.
df_day2=df_crime.groupby('day').sum()
df_day2.drop(labels=['n_killed','n_injured','n_guns_involved','male','Female'],axis=1,inplace=True)
incidents=df_crime.groupby('day')['date'].count()

df_day2['incidents']=incidents
Z = linkage(df_day2, 'single')
plt.figure(figsize=(12,6), dpi= 80)
#Dendrogram for to display which day of the week is dangerous.
dendrogram(Z, labels=df_day2.index,leaf_font_size=10);
plt.xlabel('Days')
plt.ylabel('Distance (Single)');
plt.title("Which Day of the week is dangerous?")
plt.savefig("Linkage_day_1.png");

# %% [markdown]
# ## Which Month of year has high chances of Gun violance?

# %%
#Group by "Month" field and sum the values in each filed.
df_month2=df_crime.groupby('month').sum()
df_month2.drop(labels=['n_killed','n_injured','n_guns_involved','male','Female'],axis=1,inplace=True)
incidents=df_crime.groupby('month')['date'].count()

df_month2['incidents']=incidents
Z = linkage(df_month2, 'single')
plt.figure(figsize=(12,6), dpi= 80)

#Dendrogram for to display which month of the year is dangerous.
dendrogram(Z, labels=df_month2.index,leaf_font_size=10);
plt.xlabel('Months')
plt.ylabel('Distance (Single)');
plt.title("Which month of the year is dangerous?");
plt.savefig("Linkage_year_1.png") ;

# %% [markdown]
# ## Which Top 3 US state has Highest and Lowest Kills, Injured, Guns Involved, Incidents and Total Victms?

# %%
df_state['Guns_involved']=df_crime.groupby('state',as_index=False).sum()['n_guns_involved']

# %%
#Top 3 USA states with highest victims
df_state.sort_values(['total_victim'],ascending=False).head(3)
# Out:
#          state  total_2013  total_2014  total_2015  total_2016  total_2017  \
# 13    Illinois        92.0        2913        3510        5083        4588
# 4   California       185.0        2927        2821        3161        3376
# 43       Texas        65.0        2251        2491        2927        2734
#
#     total_2018  incident_2013  incident_2014  incident_2015  incident_2016  \
# 13         737           18.0           3095           3456           5055
# 4          736           39.0           3732           3234           3617
# 43         684           11.0           3133           3276           3606
#
#     incident_2017  incident_2018  cluster  incidents  total_victim  \
# 13           5089            843        3      17556         16923
# 4            4588           1096        2      16306         13206
# 43           2875            676        2      13577         11152
#
#     Guns_involved
# 13        13524.0
# 4         16969.0
# 43         9785.0

# %%
#Top 3 USA states with highest incidents
df_state.sort_values(['incidents'],ascending=False).head(3)
# Out:
#          state  total_2013  total_2014  total_2015  total_2016  total_2017  \
# 13    Illinois        92.0        2913        3510        5083        4588
# 4   California       185.0        2927        2821        3161        3376
# 9      Florida        58.0        2336        2343        2847        2751
#
#     total_2018  incident_2013  incident_2014  incident_2015  incident_2016  \
# 13         737           18.0           3095           3456           5055
# 4          736           39.0           3732           3234           3617
# 9          646           13.0           3138           2702           4201
#
#     incident_2017  incident_2018  cluster  incidents  total_victim  \
# 13           5089            843        3      17556         16923
# 4            4588           1096        2      16306         13206
# 9            4156            819        2      15029         10981
#
#     Guns_involved
# 13        13524.0
# 4         16969.0
# 9         13207.0

# %%
#Top 3 USA states with least incidents
df_state.sort_values(['incidents'],ascending=True).head(3)
# Out:
#       state  total_2013  total_2014  total_2015  total_2016  total_2017  \
# 11   Hawaii         0.0          21          39          51          28
# 45  Vermont         0.0          47          33          23          20
# 50  Wyoming         0.0          27          36          30          22
#
#     total_2018  incident_2013  incident_2014  incident_2015  incident_2016  \
# 11           9            0.0             48             75             79
# 45           7            0.0            170            117             94
# 50          10            0.0             64            198            127
#
#     incident_2017  incident_2018  cluster  incidents  total_victim  \
# 11             68             19        0        289           148
# 45             71             20        0        472           130
# 50             91             14        0        494           125
#
#     Guns_involved
# 11          223.0
# 45          371.0
# 50          276.0

# %%
#Top 3 USA states with least victims
df_state.sort_values(['total_victim'],ascending=True).head(3)
# Out:
#       state  total_2013  total_2014  total_2015  total_2016  total_2017  \
# 50  Wyoming         0.0          27          36          30          22
# 45  Vermont         0.0          47          33          23          20
# 11   Hawaii         0.0          21          39          51          28
#
#     total_2018  incident_2013  incident_2014  incident_2015  incident_2016  \
# 50          10            0.0             64            198            127
# 45           7            0.0            170            117             94
# 11           9            0.0             48             75             79
#
#     incident_2017  incident_2018  cluster  incidents  total_victim  \
# 50             91             14        0        494           125
# 45             71             20        0        472           130
# 11             68             19        0        289           148
#
#     Guns_involved
# 50          276.0
# 45          371.0
# 11          223.0

# %%
#Top 3 USA states with highest Guns involved
df_state.sort_values(['Guns_involved'],ascending=False).head(3)
# Out:
#          state  total_2013  total_2014  total_2015  total_2016  total_2017  \
# 4   California       185.0        2927        2821        3161        3376
# 13    Illinois        92.0        2913        3510        5083        4588
# 9      Florida        58.0        2336        2343        2847        2751
#
#     total_2018  incident_2013  incident_2014  incident_2015  incident_2016  \
# 4          736           39.0           3732           3234           3617
# 13         737           18.0           3095           3456           5055
# 9          646           13.0           3138           2702           4201
#
#     incident_2017  incident_2018  cluster  incidents  total_victim  \
# 4            4588           1096        2      16306         13206
# 13           5089            843        3      17556         16923
# 9            4156            819        2      15029         10981
#
#     Guns_involved
# 4         16969.0
# 13        13524.0
# 9         13207.0

# %%
#Top 3 USA states with least Guns involved
df_state.sort_values(['Guns_involved'],ascending=True).head(3)
# Out:
#       state  total_2013  total_2014  total_2015  total_2016  total_2017  \
# 11   Hawaii         0.0          21          39          51          28
# 50  Wyoming         0.0          27          36          30          22
# 45  Vermont         0.0          47          33          23          20
#
#     total_2018  incident_2013  incident_2014  incident_2015  incident_2016  \
# 11           9            0.0             48             75             79
# 50          10            0.0             64            198            127
# 45           7            0.0            170            117             94
#
#     incident_2017  incident_2018  cluster  incidents  total_victim  \
# 11             68             19        0        289           148
# 50             91             14        0        494           125
# 45             71             20        0        472           130
#
#     Guns_involved
# 11          223.0
# 50          276.0
# 45          371.0

# %%
df_kills_inj=df_crime.groupby('state',as_index=False).sum()

# %%
df_kills_inj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   state            51 non-null     object
#  1   n_killed         51 non-null     int64
#  2   n_injured        51 non-null     int64
#  3   n_guns_involved  51 non-null     float64
#  4   total_person     51 non-null     int64
#  5   male             51 non-null     int64
#  6   Female           51 non-null     int64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 3.2+ KB

# %%
#Top 3 USA states with Highest kills
df_kills_inj.sort_values(['n_killed'],ascending=False).head(3)
# Out:
#          state  n_killed  n_injured  n_guns_involved  total_person   male  \
# 4   California      5562       7644          16969.0         13206  11337
# 43       Texas      5046       6106           9785.0         11152   8912
# 9      Florida      3909       7072          13207.0         10981   9049
#
#     Female
# 4     1869
# 43    2240
# 9     1932

# %%
#Top 3 USA states with Highest injured
df_kills_inj.sort_values(['n_injured'],ascending=False).head(3)
# Out:
#          state  n_killed  n_injured  n_guns_involved  total_person   male  \
# 13    Illinois      3409      13514          13524.0         16923  14967
# 4   California      5562       7644          16969.0         13206  11337
# 9      Florida      3909       7072          13207.0         10981   9049
#
#     Female
# 13    1956
# 4     1869
# 9     1932

# %%
#Top 3 USA states with least kills
df_kills_inj.sort_values(['n_killed'],ascending=True).head(3)
# Out:
#            state  n_killed  n_injured  n_guns_involved  total_person  male  \
# 45       Vermont        57         73            371.0           130    98
# 39  Rhode Island        63        346            700.0           409   351
# 11        Hawaii        63         85            223.0           148   122
#
#     Female
# 45      32
# 39      58
# 11      26

# %%
#Top 3 USA states with least injured
df_kills_inj.sort_values(['n_injured'],ascending=True).head(3)
# Out:
#       state  n_killed  n_injured  n_guns_involved  total_person  male  Female
# 50  Wyoming        73         52            276.0           125    90      35
# 45  Vermont        57         73            371.0           130    98      32
# 11   Hawaii        63         85            223.0           148   122      26

# %% [markdown]
# ## Does number of Gun shooting incidents and Guns involved affect the number of fatalities?

# %%
#Correlation matrix how Gun shooting incidents and Guns involved affect the number of fatalities
df_state['male']=df_crime.groupby('state',as_index=False).sum()['male']
df_state['female']=df_crime.groupby('state',as_index=False).sum()['Female']
corrMatrix = df_state[['incidents','total_victim','Guns_involved','male','female']].corr()
plt.figure(figsize=(6,4), dpi= 80)
sns.heatmap(corrMatrix, annot=True)
plt.savefig("Corr_Inci_involed_2.png") 
plt.show()

# %%
df_state.describe()
# Out:
#        total_2013   total_2014   total_2015   total_2016   total_2017  \
# count   51.000000    51.000000    51.000000    51.000000    51.000000
# mean    25.411765   697.235294   793.156863   895.019608   906.156863
# std     33.336572   740.121330   805.849449   989.859293   957.373644
# min      0.000000    21.000000    33.000000    23.000000    20.000000
# 25%      0.000000   180.500000   226.500000   224.000000   218.000000
# 50%     13.000000   409.000000   469.000000   541.000000   584.000000
# 75%     41.500000   973.500000  1154.000000  1303.000000  1367.500000
# max    185.000000  2927.000000  3510.000000  5083.000000  4588.000000
#
#        total_2018  incident_2013  incident_2014  incident_2015  incident_2016  \
# count   51.000000      51.000000      51.000000      51.000000      51.000000
# mean   190.274510       5.450980    1016.745098    1050.568627    1152.215686
# std    192.851868       7.150703     930.509277     921.828167    1111.246351
# ...

# %% [markdown]
# # Risk Score Calculation involving number of fatalities, incidents and Guns involved

# %%
# Setting up dataset for Risk score calculation for US states
x=df_crime.query('total_person == 0').groupby(['state'],as_index=False).count()[['state','date']]
df_state = pd.merge(df_state,x, on='state',how = 'left')
df_state.rename(columns={'date': 'harmless_incident'}, inplace=True)                                                                                                   
df_state['fatal_incident']=df_state['incidents']-df_state['harmless_incident']

x=df_crime.groupby(['state'],as_index=False).sum()[['state','n_killed','n_injured']]
df_state = pd.merge(df_state,x, on='state',how = 'left')
      
df_risk=df_state[['state','harmless_incident','fatal_incident','n_killed','n_injured','Guns_involved']]

# %%
#Risk score calculation on our created Dataset
risk_harmless= .15*df_risk['harmless_incident']
risk_fatal= .30*df_risk['fatal_incident']
risk_killed= .30*df_risk['n_killed']
risk_injured= .15*df_risk['n_injured']
risk_gun= .10*df_risk['Guns_involved']
risk_score=(risk_harmless+risk_fatal+risk_killed+risk_injured+risk_gun)/5
df_risk['risk_score']=risk_score
df_risk['risk_score']=round((df_risk['risk_score']/max(df_risk['risk_score']))*100)

df_risk.sort_values('risk_score',ascending=False,inplace=True)

# %%
df_state.sort_values('total_victim',ascending=False,inplace=True)

# %%
# Providing Rank to Datasets
rank=list(range(1, 52))
df_risk['Rank']=rank
df_state['Rank']=rank

# %%
x=df_state[['state','Rank']]
df_risk.rename(columns={'Rank': 'Risk_Rank'}, inplace=True)           
# Merging to calculate change in Rank for dangerous US state
df_risk = pd.merge(df_risk,x, on='state',how = 'left')
df_risk.rename(columns={'Rank': 'Previous_Rank'}, inplace=True)
df_risk['Rank_Change']=-(df_risk['Risk_Rank']-df_risk['Previous_Rank'])

# %%
df_risk
# Out:
#                    state  harmless_incident  fatal_incident  n_killed  \
# 0               Illinois               4014           13542      3409
# 1             California               6335            9971      5562
# 2                Florida               6680            8349      3909
# 3                  Texas               4947            8630      5046
# 4                   Ohio               3554            6690      2508
# 5           Pennsylvania               2973            5956      2395
# 6               New York               4298            5414      1705
# 7         North Carolina               3227            5512      2225
# 8                Georgia               3811            5114      2456
# 9              Louisiana               2847            5256      2179
# 10             Tennessee               2546            5080      1824
# 11              Missouri               2208            4423      2136
# ...

# %%
# Setting up dataset for Risk score calculation for Month of Year
df_month_risk=df_crime.query('total_person == 0').groupby('month',as_index=False).count()[['month','date']]
df_month_risk.rename(columns={'date': 'harmless_incident'}, inplace=True)   
df_month_risk['fatal_incident']=df_crime.query('total_person > 0').groupby('month',as_index=False).count()['date']
x=df_crime.groupby('month',as_index=False).sum()[['month','n_killed','n_injured','n_guns_involved']]
df_month_risk= pd.merge(df_month_risk,x, on='month',how = 'left')

#Risk score calculation on our created Dataset
risk_harmless= .15*df_month_risk['harmless_incident']
risk_fatal= .30*df_month_risk['fatal_incident']
risk_killed= .30*df_month_risk['n_killed']
risk_injured= .15*df_month_risk['n_injured']
risk_gun= .10*df_month_risk['n_guns_involved']
risk_score=(risk_harmless+risk_fatal+risk_killed+risk_injured+risk_gun)/5
df_month_risk['risk_score']=risk_score
df_month_risk['risk_score']=round((df_month_risk['risk_score']/max(df_month_risk['risk_score']))*100)
df_month_risk.sort_values('risk_score',ascending=False,inplace=True)
x=df_crime.groupby('month',as_index=False).sum()[['month','total_person']]
x.sort_values('total_person',ascending=False,inplace=True)

# Providing Rank to Datasets
rank=list(range(1, 13))
df_month_risk['Risk_Rank']=rank
x['Rank']=rank
df_month_risk['Previous_Rank']=x['Rank']

# calculate change in Rank for dangerous Month of year
df_month_risk['Rank_Change']=-(df_month_risk['Risk_Rank']-df_month_risk['Previous_Rank'])

# %%
df_month_risk
# Out:
#         month  harmless_incident  fatal_incident  n_killed  n_injured  \
# 4     January               9339           13752      6035      10946
# 7       March               9832           12808      5641      10475
# 1      August               8536           12504      5127      10809
# 5        July               8185           12941      5276      11259
# 8         May               7944           11986      4830      10244
# 10    October               8222           11668      4791       9756
# 11  September               8157           11499      4779       9766
# 2    December               6804           11302      4927       8936
# 6        June               7259           11496      4886       9797
# 3    February               8169           10672      4945       8420
# 9    November               6866           11108      4848       9087
# 0       April               7974           10654      4383       8907
#
# ...

# %%
# Setting up dataset for Risk score calculation for Day of Week
df_day_risk=df_crime.query('total_person == 0').groupby('day',as_index=False).count()[['day','date']]
df_day_risk.rename(columns={'date': 'harmless_incident'}, inplace=True)   
df_day_risk['fatal_incident']=df_crime.query('total_person > 0').groupby('day',as_index=False).count()['date']
x=df_crime.groupby('day',as_index=False).sum()[['day','n_killed','n_injured','n_guns_involved']]
df_day_risk= pd.merge(df_day_risk,x, on='day',how = 'left')

#Risk score calculation on our created Dataset
risk_harmless= .15*df_day_risk['harmless_incident']
risk_fatal= .30*df_day_risk['fatal_incident']
risk_killed= .30*df_day_risk['n_killed']
risk_injured= .15*df_day_risk['n_injured']
risk_gun= .10*df_day_risk['n_guns_involved']
risk_score=(risk_harmless+risk_fatal+risk_killed+risk_injured+risk_gun)/5
df_day_risk['risk_score']=risk_score
df_day_risk['risk_score']=round((df_day_risk['risk_score']/max(df_day_risk['risk_score']))*100)
df_day_risk.sort_values('risk_score',ascending=False,inplace=True)
x=df_crime.groupby('day',as_index=False).sum()[['day','total_person']]
x.sort_values('total_person',ascending=False,inplace=True)

# Providing Rank to Datasets
rank=list(range(1,8))
df_day_risk['Risk_Rank']=rank
x['Rank']=rank
df_day_risk['Previous_Rank']=x['Rank']

# calculate change in Rank for dangerous Day of week
df_day_risk['Rank_Change']=-(df_day_risk['Risk_Rank']-df_day_risk['Previous_Rank'])

# %%
df_day_risk
# Out:
#          day  harmless_incident  fatal_incident  n_killed  n_injured  \
# 2   Saturday              12555           23541      9813      20559
# 3     Sunday              12979           24073     10187      21562
# 1     Monday              13885           19875      8383      16164
# 6  Wednesday              15191           18935      8083      15193
# 5    Tuesday              14430           18877      7917      15168
# 0     Friday              13753           19022      8353      15275
# 4   Thursday              14494           18067      7732      14481
#
#    n_guns_involved  risk_score  Risk_Rank  Previous_Rank  Rank_Change
# 2          29359.0       100.0          1              2            1
# 3          25387.0       100.0          2              1           -1
# 1          26158.0        87.0          3              3            0
# 6          29157.0        87.0          4              5            1
# ...

# %% [markdown]
# ## Which Day of week can see high Gun violance based on Risk score?

# %%
# Bar chart to show which day of week is safer and dangerous
fig, ax = plt.subplots(figsize=(8,6))
barplot = plt.bar(df_day_risk.day, df_day_risk.risk_score, color = 'green', alpha = 0.85,width=0.4)
barplot[0].set_color('#DA0D0D')
barplot[1].set_color('#DA0D0D')
barplot[2].set_color('#FF7511')
barplot[3].set_color('#FF7511')
barplot[4].set_color('#FF7511')
barplot[5].set_color('#00C411')
barplot[6].set_color('#00C411')
plt.xticks(ticks=df_day_risk.day,fontsize = 11)
plt.xlabel('Day', fontsize = 12, weight = 'bold')
plt.ylabel('Risk score', fontsize = 12, weight = 'bold')
plt.title('Which day in week has high risk for gun violance?', fontsize = 12, weight = 'bold')
plt.savefig("Risk_Rank_day_1.png") 

plt.show()

# %% [markdown]
# ## Which Month of year can see high Gun violance based on Risk score?

# %%
# Bar chart to show which month of year is safer and dangerous
fig, ax = plt.subplots(figsize=(14,6))
barplot = plt.bar(df_month_risk.month, df_month_risk.risk_score, color = 'green', alpha = .85,width=0.4)
barplot[0].set_color('#DA0D0D')
barplot[1].set_color('#DA0D0D')
barplot[2].set_color('#FF7511')
barplot[3].set_color('#FF7511')
barplot[4].set_color('#FF7511')
barplot[10].set_color('#00C411')
barplot[11].set_color('#00C411')
plt.xticks(ticks=df_month_risk.month,fontsize = 10)
plt.xlabel('Month', fontsize = 12, weight = 'bold')
plt.ylabel('Risk score', fontsize = 12, weight = 'bold')
plt.title('Which month in year has high risk for gun violance?', fontsize = 12, weight = 'bold')
plt.savefig("Risk_Rank_month_1.png") 
plt.show()

# %% [markdown]
# ## Which USA State has high chance of Gun violance based on Risk score generated?

# %%
# Bar chart to show which state is safer and dangerous
df_risk.sort_values('risk_score', inplace=True,ascending=True)

likeability_scores = np.array(df_risk.risk_score)
 
data_normalizer = mp.colors.Normalize()
color_map = mp.colors.LinearSegmentedColormap(
    "my_map",
    {
        "red": [(0, 1.0, 1.0),
                (1.0, .5, .5)],
        "green": [(0, 0.5, 0.5),
                  (1.0, 0, 0)],
        "blue": [(0, 0.50, 0.5),
                 (1.0, 0, 0)]
    }
)


plt.figure(figsize=(14,10), dpi= 80)
plt.barh(df_risk.state, df_risk.risk_score, align='center',color=color_map(data_normalizer(likeability_scores)))


plt.ylabel('State', fontsize = 12, weight = 'bold')
plt.xlabel('Risk Score', fontsize = 12, weight = 'bold')
plt.title('Which state is safer based on prediction score?', fontdict={'size':12},weight = 'bold')
plt.savefig("Risk_Rank_state_1.png",dpi='figure',quality=100) 
plt.show()

# %% [markdown]
# ## How Does the safety ranking of USA state affect based on Risk score generated?

# %%
# Safety ranking of USA state affect based on Risk score generated
# Prepare Data

df_risk['colors'] = ['red' if x < 0 else 'green' for x in df_risk['Rank_Change']]
df_risk1=df_risk.copy()
df_risk1.sort_values('Rank_Change', inplace=True)

# %%
# Draw plot
plt.figure(figsize=(14,10), dpi= 80)
plt.hlines(y=df_risk1.state, xmin=0, xmax=df_risk1.Rank_Change, color=df_risk1['colors'], alpha=0.7, linewidth=5)

# Decorations
plt.gca().set(ylabel='State', xlabel='Change in Rank')
plt.yticks(df_risk1.state, fontsize=10)
plt.ylabel('State', fontsize = 12, weight = 'bold')
plt.xlabel('Change in rank', fontsize = 12, weight = 'bold')
plt.title('Change in Rank after Risk Score prediction', fontsize = 12, weight = 'bold')
plt.grid(linestyle='--', alpha=0.5)
plt.savefig("Risk_Rank_change_1.png") 
plt.show()

# %% [markdown]
# # Risk calculation involving Population, Per-capita income and Un-employment in US States.

# %%
# Prepare dataset from main DATASET(Dataset1)
df_state_risk=df_risk[['state','harmless_incident','fatal_incident','n_killed','n_injured','Guns_involved','Previous_Rank']]
df_state_risk['harmless_incident']=(df_state_risk['harmless_incident']/max(df_state_risk['harmless_incident']))*100
df_state_risk['fatal_incident']=(df_state_risk['fatal_incident']/max(df_state_risk['fatal_incident']))*100
df_state_risk['n_killed']=(df_state_risk['n_killed']/max(df_state_risk['n_killed']))*100
df_state_risk['n_injured']=(df_state_risk['n_injured']/max(df_state_risk['n_injured']))*100
df_state_risk['Guns_involved']=(df_state_risk['Guns_involved']/max(df_state_risk['Guns_involved']))*100

# %%
# Prepare datset from Population_Un-Employment_Per-capita(Dataset2)
df_state_risk.rename(columns={'state': 'State'}, inplace=True)
x=df_capita[['State','Pop']]
y=df_state_risk['State']
df_capita_state=pd.merge(y,x, on='State',how = 'left')
x=df_risk[['state','n_killed']]
x.rename(columns={'state': 'State'}, inplace=True)

df_capita_state=pd.merge(df_capita_state,x, on='State',how = 'left')

df_capita_state['Avg_Death_Rate']=((df_capita_state['n_killed']/df_capita_state['Pop'])*100000)

x=df_capita[['State','Per_Capita_2018','Per_Capita_2017','Per_Capita_2016','Per_Capita_2015','Per_Capita_2014','Per_Capita_2013','Une_Rate_2018','Une_Rate_2017','Une_Rate_2016','Une_Rate_2015','Une_Rate_2014','Une_Rate_2013']]
x['Avg_per_capita']=(x['Per_Capita_2018']+x['Per_Capita_2017']+x['Per_Capita_2016']+x['Per_Capita_2015']+x['Per_Capita_2014']+x['Per_Capita_2013'])/6
x['Avg_Un_Emp']=(x['Une_Rate_2018']+x['Une_Rate_2017']+x['Une_Rate_2016']+x['Une_Rate_2015']+x['Une_Rate_2014']+x['Une_Rate_2013'])/6

y=x[['State','Avg_per_capita','Avg_Un_Emp']]

df_capita_state=pd.merge(df_capita_state,y, on='State',how = 'left')

# %%
df_capita=df_capita_state.copy()

# %%
df_capita.sort_values('Avg_Un_Emp',inplace=True)
df_capita.reset_index(inplace=True,drop=True)
df_capita
# Out:
#                    State         Pop  n_killed  Avg_Death_Rate  \
# 0           North Dakota    761723.0        69        9.058411
# 1               Nebraska   1952570.0       225       11.523274
# 2           South Dakota    903027.0        90        9.966479
# 3                Vermont    628061.0        57        9.075552
# 4                 Hawaii   1412687.0        63        4.459587
# 5          New Hampshire   1371246.0        88        6.417521
# 6                   Utah   3282115.0       282        8.592021
# 7                   Iowa   3179849.0       273        8.585313
# 8              Minnesota   5700671.0       461        8.086767
# 9                  Idaho   1826156.0       166        9.090132
# 10                Kansas   2910357.0       542       18.623145
# 11              Colorado   5845526.0       796       13.617252
# 12               Montana   1086759.0       154       14.170575
# 13              Virginia   8626207.0      1459       16.913575
# ...

# %%
plt.figure(figsize=(14,10), dpi= 80)
df_capita['colors'] = ['red' if x >= df_capita.Avg_Un_Emp.mean() else 'green' for x in df_capita.Avg_Un_Emp]
plt.hlines(y=df_capita.State, xmin=0, xmax=df_capita.Avg_Un_Emp, color=df_capita['colors'])
plt.plot(df_capita.Avg_Un_Emp, df_capita.State, "o")
plt.axvline(x = df_capita.Avg_Un_Emp.mean(),linestyle='--') 
plt.annotate('National Un-Employment Average', xy=(5.1, 3), xytext=(5.5, 9),
            arrowprops=dict(facecolor='black', shrink=0.05),fontsize = 10)
# Add titles and axis names
plt.yticks(df_capita.State,fontsize = 10)
plt.title("Average Un-Employment rate from 2013 to 2018 for US State's  ")
plt.xlabel('Un-Employment Rate',fontsize = 12, weight = 'bold')
plt.ylabel('State',fontsize = 12, weight = 'bold')
plt.savefig("US_Un_Emp.png",dpi='figure',quality=100);

# %%
df_capita.sort_values('Avg_per_capita',inplace=True)
df_capita.reset_index(inplace=True,drop=True)

# %%
df_capita['colors'] = ['red' if x >= df_capita.Avg_per_capita.mean() else 'green' for x in df_capita.Avg_per_capita]
fig, ax = plt.subplots(figsize=(16,10), dpi= 80)
plt.hlines(y=df_capita.State, xmin=0, xmax=df_capita.Avg_per_capita, color='gray', alpha=0.7, linewidth=1, linestyles='dashdot')
plt.scatter(y=df_capita.State, x=df_capita.Avg_per_capita, s=75, color='firebrick', alpha=0.7)
plt.axvline(x = df_capita.Avg_per_capita.mean(),linestyle='--') 
plt.annotate('National Per-Capita income Average', xy=(56000, 3), xytext=(58000, 9),
            arrowprops=dict(facecolor='black', shrink=0.05),fontsize = 12)
# Title, Label, Ticks and Ylim
plt.yticks(df_capita.State,fontsize = 11)
plt.title("Average Per-Capita income from 2013 to 2018 for US State's  ",fontsize = 14)
plt.xlabel('Per-Capita income',fontsize = 12, weight = 'bold')
plt.ylabel('State',fontsize = 12, weight = 'bold')
plt.savefig("US_Per_capita.png",dpi='figure',quality=100);

# %%
df_capita.Avg_per_capita.mean()
# Out:
# 55265.91503267975

# %%
df_capita.Avg_Un_Emp.mean()
# Out:
# 5.039542483660131

# %%
df_capita['Not_Safe'] = ['Yes' if x >= df_capita.Avg_Death_Rate.mean() else 'No' for x in df_capita.Avg_Death_Rate]

# %%
df_capita['More_than_per_capita'] = ['Yes' if x >= df_capita.Avg_per_capita.mean() else 'No' for x in df_capita.Avg_per_capita]

# %%
df_capita['More_than_Un_Emp'] = ['Yes' if x >= df_capita.Avg_Un_Emp.mean() else 'No' for x in df_capita.Avg_Un_Emp]

# %%
df_capita
# Out:
#                    State         Pop  n_killed  Avg_Death_Rate  \
# 0          West Virginia   1778070.0       335       18.840653
# 1               Kentucky   4499692.0      1066       23.690510
# 2               Arkansas   3038999.0       773       25.436007
# 3            Mississippi   2989260.0      1176       39.340840
# 4                Alabama   4908621.0      1880       38.299962
# 5             New Mexico   2096640.0       495       23.609203
# 6              Louisiana   4645184.0      2179       46.908798
# 7         South Carolina   5210095.0      1610       30.901548
# 8              Tennessee   6897576.0      1824       26.444073
# 9               Oklahoma   3954821.0       941       23.793744
# 10        North Carolina  10611862.0      2225       20.967103
# 11                 Idaho   1826156.0       166        9.090132
# 12               Montana   1086759.0       154       14.170575
# 13               Florida  21992985.0      3909       17.773849
# ...

# %%
df_capita['Avg_Death_Rate'].mean()
# Out:
# 19.03788618840494

# %%
#proportion of states more than National per capita average
More_than_per_capita_yes = df_capita[df_capita["More_than_per_capita"]=="Yes"]
total = df_capita.shape[0]
More_than_per_capita_yes.shape[0]/total
# Out:
# 0.43137254901960786

# %%
More_than_per_capita_yes['Avg_Death_Rate'].mean()
# Out:
# 13.898720092283982

# %%
prop = []
for _ in range(1000):
    sample = df_capita.sample(20,replace=True)
    More_than_per_capita_yes = sample[sample["More_than_per_capita"]=="Yes"]
    prop.append(More_than_per_capita_yes['Avg_Death_Rate'].mean())

# %%
prop = np.array(prop)
prop.mean()
# Out:
# 13.816073214984723

# %%
np.percentile(prop,5),np.percentile(prop,95)
# Out:
# (9.531667686582015, 19.093735414578465)

# %%
#proportion of states less than National per capita average
More_than_per_capita_no = df_capita[df_capita["More_than_per_capita"]=="No"]
total = df_capita.shape[0]
More_than_per_capita_no.shape[0]/total
# Out:
# 0.5686274509803921

# %%
More_than_per_capita_no['Avg_Death_Rate'].mean()
# Out:
# 22.9365639164967

# %%
prop = []
for _ in range(1000):
    sample = df_capita.sample(20,replace=True)
    More_than_per_capita_no = sample[sample["More_than_per_capita"]=="No"]
    prop.append(More_than_per_capita_no['Avg_Death_Rate'].mean())

# %%
prop = np.array(prop)
prop.mean()
# Out:
# 23.054251241797118

# %%
np.percentile(prop,5),np.percentile(prop,95)
# Out:
# (17.434630229752937, 29.644323009547634)

# %%
#proportion of states more than National Un-Employment average
More_than_Un_Emp_yes = df_capita[df_capita["More_than_Un_Emp"]=="Yes"]
total = df_capita.shape[0]
More_than_Un_Emp_yes.shape[0]/total
# Out:
# 0.5098039215686274

# %%
More_than_Un_Emp_yes['Avg_Death_Rate'].mean()
# Out:
# 23.28351418957728

# %%
prop = []
for _ in range(1000):
    sample = df_capita.sample(20,replace=True)
    More_than_Un_Emp_yes = sample[sample["More_than_Un_Emp"]=="Yes"]
    prop.append(More_than_Un_Emp_yes['Avg_Death_Rate'].mean())

# %%
prop = np.array(prop)
prop.mean()
# Out:
# 23.428655952610242

# %%
np.percentile(prop,5),np.percentile(prop,95)
# Out:
# (16.996665102207068, 31.075031888914275)

# %%
#proportion of states less than National Un-Employment average
More_than_Un_Emp_no = df_capita[df_capita["More_than_Un_Emp"]=="No"]
total = df_capita.shape[0]
More_than_Un_Emp_no.shape[0]/total
# Out:
# 0.49019607843137253

# %%
More_than_Un_Emp_no['Avg_Death_Rate'].mean()
# Out:
# 14.622433067185703

# %%
prop = []
for _ in range(1000):
    sample = df_capita.sample(20,replace=True)
    More_than_Un_Emp_no = sample[sample["More_than_Un_Emp"]=="No"]
    prop.append(More_than_Un_Emp_no['Avg_Death_Rate'].mean())

# %%
prop = np.array(prop)
prop.mean()
# Out:
# 14.518910518866052

# %%
np.percentile(prop,5),np.percentile(prop,95)
# Out:
# (10.357278188191819, 18.843193702630085)

# %%
#proportion of states more than National death average
Not_safe_yes = df_capita[df_capita["Not_Safe"]=="Yes"]
total = df_capita.shape[0]
Not_safe_yes.shape[0]/total
# Out:
# 0.39215686274509803

# %%
#proportion of states less than National death average
Not_safe_No = df_capita[df_capita["Not_Safe"]=="No"]
total = df_capita.shape[0]
Not_safe_No.shape[0]/total
# Out:
# 0.6078431372549019

# %%
Not_safe_yes['Avg_Un_Emp'].mean()
# Out:
# 5.664166666666666

# %%
Not_safe_yes['Avg_per_capita'].mean()
# Out:
# 51132.04166666667

# %%
Not_safe_No['Avg_Un_Emp'].mean()
# Out:
# 4.636559139784945

# %%
Not_safe_No['Avg_per_capita'].mean()
# Out:
# 57932.930107526874

# %%
prop = []
for _ in range(1000):
    sample = df_capita.sample(20,replace=True)
    Not_safe_no = sample[sample["Not_Safe"]=="No"]
    prop.append(Not_safe_no['Avg_Un_Emp'].mean())

# %%
prop = np.array(prop)
prop.mean()
# Out:
# 4.634126796836777

# %%
np.percentile(prop,5),np.percentile(prop,95)
# Out:
# (4.142948232323231, 5.09175)

# %%
prop = []
for _ in range(1000):
    sample = df_capita.sample(20,replace=True)
    Not_safe_yes = sample[sample["Not_Safe"]=="Yes"]
    prop.append(Not_safe_yes['Avg_Un_Emp'].mean())

# %%
prop = np.array(prop)
prop.mean()
# Out:
# nan

# %%
np.percentile(prop,5),np.percentile(prop,95)
# Out:
# (nan, nan)

# %%
prop = []
for _ in range(1000):
    sample = df_capita.sample(20,replace=True)
    Not_safe_no = sample[sample["Not_Safe"]=="No"]
    prop.append(Not_safe_no['Avg_per_capita'].mean())

# %%
prop = np.array(prop)
prop.mean()
# Out:
# 57866.840770941126

# %%
np.percentile(prop,5),np.percentile(prop,95)
# Out:
# (54453.2641025641, 61314.594760101)

# %%
prop = []
for _ in range(1000):
    sample = df_capita.sample(20,replace=True)
    Not_safe_yes = sample[sample["Not_Safe"]=="Yes"]
    prop.append(Not_safe_yes['Avg_per_capita'].mean())

# %%
prop = np.array(prop)
prop.mean()
# Out:
# 51099.16868659165

# %%
np.percentile(prop,5),np.percentile(prop,95)
# Out:
# (46571.346666666665, 56604.48214285715)

# %%
# Prepare dataset for Risk calculation
df_capita_state['Avg_per_capita']=(df_capita_state['Avg_per_capita']/max(df_capita_state['Avg_per_capita']))*100

df_capita_state['Avg_Un_Emp']=(df_capita_state['Avg_Un_Emp']/max(df_capita_state['Avg_Un_Emp']))*100
df_capita_state['Pop']=(df_capita_state['Pop']/max(df_capita_state['Pop']))*100
df_capita_state['Death_Rate']=(df_capita_state['Avg_Death_Rate']/max(df_capita_state['Avg_Death_Rate']))*100
df_capita_state.dropna(inplace=True)

# %%
# Prepare datset from Population_Gun-permit_Eduction_Sucide-Rate(Dataset3)
for item in df_Gun_Edu['Permit'].index:
    if(df_Gun_Edu['Permit'][item]=="Yes"):
        df_Gun_Edu['Permit'][item]=100
    else:
        df_Gun_Edu['Permit'][item]=0

df_Gun_Edu['Permit']=df_Gun_Edu['Permit'].astype(int)

# %%
# Prepare dataset for Risk calculation
df_state_permit=df_Gun_Edu[['State','Permit','High school graduate or higher','Sucide Death Rate']]
df_state_permit['High school graduate or higher']=(df_state_permit['High school graduate or higher']/max(df_state_permit['High school graduate or higher']))*100
df_state_permit['Sucide Death Rate']=(df_state_permit['Sucide Death Rate']/max(df_state_permit['Sucide Death Rate']))*100

# %%
# Merging Dataset created from Population_Un-Employment_Per-capita(Dataset2) and dataset from main dataset(dataset1)
df_state_risk= pd.merge(df_state_risk,df_capita_state, on='State',how = 'left')
# Merging Dataset created from Population_Gun-permit_Eduction_Sucide-Rate(Dataset3) and dataset from main dataset(dataset1)
df_state_risk= pd.merge(df_state_risk,df_state_permit, on='State',how = 'left')

# Copying created dataset for Risk calculation
df_state_pop=df_state_risk.copy()
df_state_all=df_state_risk.copy()
df_state_emp=df_state_risk.copy()
df_state_per=df_state_risk.copy()
df_state_edu=df_state_risk.copy()
df_state_suc=df_state_risk.copy()

# %%
df_state_risk
# Out:
#                    State  harmless_incident  fatal_incident  n_killed_x  \
# 0                 Hawaii           2.514970        0.893516    1.132686
# 1           North Dakota           6.002994        1.270123    1.240561
# 2                Wyoming           5.823353        0.775366    1.312478
# 3           South Dakota           5.583832        1.262738    1.618123
# 4                Vermont           5.389222        0.827057    1.024811
# 5                  Idaho           5.988024        1.927337    2.984538
# 6          New Hampshire          11.317365        1.535962    1.582165
# 7                  Maine          10.688623        1.425196    2.013664
# 8                Montana           6.047904        1.727957    2.768788
# 9           Rhode Island           8.502994        2.414710    1.132686
# 10                  Utah           7.829341        4.054054    5.070119
# 11                Alaska          12.724551        3.684832    4.800431
# ...

# %%
#Risk score calculation on our created Dataset
risk_harmless= .05*df_state_pop['harmless_incident']
risk_fatal= .10*df_state_pop['fatal_incident']
risk_Death_Rate= .35*df_state_pop['Death_Rate']
risk_gun= .10*df_state_pop['Guns_involved']
risk_injured= .05*df_state_pop['n_injured']
risk_capita= .35*df_state_pop['Avg_per_capita']
risk_score=(risk_harmless+risk_fatal+risk_Death_Rate+risk_injured+risk_gun-risk_capita)/6
df_state_pop['risk_score']=risk_score
df_state_pop['risk_score']=round((df_state_pop['risk_score']/max(df_state_pop['risk_score']))*100)
df_state_pop.sort_values('risk_score',ascending=False,inplace=True)

rank=list(range(1,52))
df_state_pop['Risk_Rank']=rank


df_state_pop['Rank_Change']=-(df_state_pop['Risk_Rank']-df_state_pop['Previous_Rank'])

# %%
df_state_pop
# Out:
#                    State  harmless_incident  fatal_incident  n_killed_x  \
# 41             Louisiana          42.619760       38.812583   39.176555
# 23  District of Columbia          25.658683       10.936346    8.252427
# 50              Illinois          60.089820      100.000000   61.290903
# 48               Florida         100.000000       61.652636   70.280475
# 33               Alabama          22.769461       29.168513   33.800791
# 28           Mississippi          16.931138       18.224782   21.143474
# 39              Missouri          33.053892       32.661350   38.403452
# 38        South Carolina          46.676647       28.215921   28.946422
# 46                  Ohio          53.203593       49.401861   45.091694
# 40             Tennessee          38.113772       37.512923   32.793959
# 49            California          94.835329       73.630188  100.000000
# 47                 Texas          74.056886       63.727662   90.722762
# ...

# %%
#Risk score calculation on our created Dataset
risk_harmless= .05*df_state_emp['harmless_incident']
risk_fatal= .10*df_state_emp['fatal_incident']
risk_Death_Rate= .35*df_state_emp['Death_Rate']
risk_gun= .10*df_state_emp['Guns_involved']
risk_injured= .05*df_state_emp['n_injured']
risk_emp= .35*df_state_emp['Avg_Un_Emp']
risk_score=(risk_harmless+risk_fatal+risk_Death_Rate+risk_injured+risk_gun+risk_emp)/6
df_state_emp['risk_score']=risk_score
df_state_emp['risk_score']=round((df_state_emp['risk_score']/max(df_state_emp['risk_score']))*100)
df_state_emp.sort_values('risk_score',ascending=False,inplace=True)

rank=list(range(1,52))
df_state_emp['Risk_Rank']=rank


df_state_emp['Rank_Change']=-(df_state_emp['Risk_Rank']-df_state_emp['Previous_Rank'])

# %%
df_state_emp
# Out:
#                    State  harmless_incident  fatal_incident  n_killed_x  \
# 23  District of Columbia          25.658683       10.936346    8.252427
# 50              Illinois          60.089820      100.000000   61.290903
# 41             Louisiana          42.619760       38.812583   39.176555
# 49            California          94.835329       73.630188  100.000000
# 28           Mississippi          16.931138       18.224782   21.143474
# 48               Florida         100.000000       61.652636   70.280475
# 33               Alabama          22.769461       29.168513   33.800791
# 11                Alaska          12.724551        3.684832    4.800431
# 46                  Ohio          53.203593       49.401861   45.091694
# 42               Georgia          57.050898       37.763994   44.156778
# 38        South Carolina          46.676647       28.215921   28.946422
# 39              Missouri          33.053892       32.661350   38.403452
# ...

# %%
# Bar chart to show which state is safer and dangerous based on death rate for every 100,000 population
df_state_pop.sort_values('Avg_Death_Rate', inplace=True,ascending=True)

likeability_scores = np.array(df_state_pop.Avg_Death_Rate)
 
data_normalizer = mp.colors.Normalize()
color_map = mp.colors.LinearSegmentedColormap(
    "my_map",
    {
        "red": [(0, 1.0, 1.0),
                (1.0, .5, .5)],
        "green": [(0, 0.5, 0.5),
                  (1.0, 0, 0)],
        "blue": [(0, 0.50, 0.5),
                 (1.0, 0, 0)]
    }
)


plt.figure(figsize=(14,10), dpi= 80)
plt.barh(df_state_pop.State, df_state_pop.Avg_Death_Rate, align='center',color=color_map(data_normalizer(likeability_scores)))

plt.axvline(x = df_state_pop.Avg_Death_Rate.mean(),linestyle='--')
plt.annotate('National Gun Shooting Death Average', xy=(20, 3), xytext=(23, 9),
            arrowprops=dict(facecolor='black', shrink=0.05),fontsize = 12)
plt.ylabel('State', fontsize = 12, weight = 'bold')
plt.xlabel('Death rate for every 100,000 population', fontsize = 12, weight = 'bold')
plt.title('Which state is safer based on death rate for every 100,000 population?', fontdict={'size':12},weight = 'bold')
plt.savefig("Death_state.png",dpi='figure',quality=100) 
plt.show()

# %%
df_state_pop.Avg_Death_Rate.mean()
# Out:
# 19.037886188404936

# %%
# Bar chart to show which state is safer and dangerous based on involving Population and Per-Capita income
df_state_pop.sort_values('risk_score', inplace=True,ascending=True)

likeability_scores = np.array(df_state_pop.risk_score)
 
data_normalizer = mp.colors.Normalize()
color_map = mp.colors.LinearSegmentedColormap(
    "my_map",
    {
        "red": [(0, 1.0, 1.0),
                (1.0, .5, .5)],
        "green": [(0, 0.5, 0.5),
                  (1.0, 0, 0)],
        "blue": [(0, 0.50, 0.5),
                 (1.0, 0, 0)]
    }
)


plt.figure(figsize=(14,10), dpi= 80)
plt.barh(df_state_pop.State, df_state_pop.risk_score, align='center',color=color_map(data_normalizer(likeability_scores)))


plt.ylabel('State', fontsize = 12, weight = 'bold')
plt.xlabel('Risk Score', fontsize = 12, weight = 'bold')
plt.title('Which state is safer based on prediction score involving Population and Per-Capita income?', fontdict={'size':12},weight = 'bold')
plt.savefig("Risk_Rank_state_2.png",dpi='figure',quality=100) 
plt.show()

# %%
# Safety ranking of USA state affect based on Risk score generated
# Prepare Data

df_state_pop['colors'] = ['red' if x < 0 else 'green' for x in df_state_pop['Rank_Change']]
df_state_pop.sort_values('Rank_Change', inplace=True)
df_state_pop.reset_index(inplace=True)
# Draw plot
plt.figure(figsize=(14,10), dpi= 80)
plt.hlines(y=df_state_pop.State, xmin=0, xmax=df_state_pop.Rank_Change, color=df_state_pop['colors'], alpha=0.7, linewidth=5)

# Decorations
plt.gca().set(ylabel='State', xlabel='Change in Rank')
plt.yticks(df_state_pop.State, fontsize=10)
plt.ylabel('State', fontsize = 12, weight = 'bold')
plt.xlabel('Change in rank', fontsize = 12, weight = 'bold')
plt.title('Change in Rank after Risk Score prediction', fontsize = 12, weight = 'bold')
plt.grid(linestyle='--', alpha=0.5)
plt.savefig("Risk_Rank_change_2.png") 
plt.show()

# %%
# Bar chart to show which state is safer and dangerous based on involving Population and Unemployment rate
df_state_emp.sort_values('risk_score', inplace=True,ascending=True)

likeability_scores = np.array(df_state_emp.risk_score)
 
data_normalizer = mp.colors.Normalize()
color_map = mp.colors.LinearSegmentedColormap(
    "my_map",
    {
        "red": [(0, 1.0, 1.0),
                (1.0, .5, .5)],
        "green": [(0, 0.5, 0.5),
                  (1.0, 0, 0)],
        "blue": [(0, 0.50, 0.5),
                 (1.0, 0, 0)]
    }
)


plt.figure(figsize=(14,10), dpi= 80)
plt.barh(df_state_emp.State, df_state_emp.risk_score, align='center',color=color_map(data_normalizer(likeability_scores)))


plt.ylabel('State', fontsize = 12, weight = 'bold')
plt.xlabel('Risk Score', fontsize = 12, weight = 'bold')
plt.title('Which state is safer based on prediction score involving Population and Unemployment rate?', fontdict={'size':12},weight = 'bold')
plt.savefig("Risk_Rank_state_3.png",dpi='figure',quality=100) 
plt.show()

# %%
# Safety ranking of USA state affect based on Risk score generated
# Prepare Data

df_state_emp['colors'] = ['red' if x < 0 else 'green' for x in df_state_emp['Rank_Change']]
df_state_emp.sort_values('Rank_Change', inplace=True)
df_state_emp.reset_index(inplace=True)
# Draw plot
plt.figure(figsize=(14,10), dpi= 80)
plt.hlines(y=df_state_emp.State, xmin=0, xmax=df_state_emp.Rank_Change, color=df_state_emp['colors'], alpha=0.7, linewidth=5)

# Decorations
plt.gca().set(ylabel='State', xlabel='Change in Rank')
plt.yticks(df_state_emp.State, fontsize=10)
plt.ylabel('State', fontsize = 12, weight = 'bold')
plt.xlabel('Change in rank', fontsize = 12, weight = 'bold')
plt.title('Change in Rank after Risk Score prediction', fontsize = 12, weight = 'bold')
plt.grid(linestyle='--', alpha=0.5)
plt.savefig("Risk_Rank_change_3.png") 
plt.show()

# %%
df_state_risk[['State','Avg_Death_Rate']].sort_values('Avg_Death_Rate',ascending=False).head(10)
# Out:
#                    State  Avg_Death_Rate
# 23  District of Columbia       63.689230
# 41             Louisiana       46.908798
# 28           Mississippi       39.340840
# 33               Alabama       38.299962
# 11                Alaska       36.375923
# 39              Missouri       34.623221
# 38        South Carolina       30.901548
# 35              Maryland       27.798253
# 50              Illinois       26.928007
# 40             Tennessee       26.444073

# %%
df_state_risk[['State','Avg_Death_Rate']].sort_values('Avg_Death_Rate',ascending=False).tail(10)
# Out:
#             State  Avg_Death_Rate
# 1    North Dakota        9.058411
# 44       New York        8.770365
# 10           Utah        8.592021
# 17           Iowa        8.585313
# 7           Maine        8.322249
# 19      Minnesota        8.086767
# 31  Massachusetts        6.765476
# 6   New Hampshire        6.417521
# 9    Rhode Island        5.965000
# 0          Hawaii        4.459587

# %%
df_capita[['State','Avg_per_capita']].sort_values('Avg_per_capita',ascending=False).tail(10)
# Out:
#             State  Avg_per_capita
# 9        Oklahoma    47857.000000
# 8       Tennessee    47166.500000
# 7  South Carolina    46574.333333
# 6       Louisiana    45213.166667
# 5      New Mexico    44791.166667
# 4         Alabama    44526.333333
# 3     Mississippi    43633.666667
# 2        Arkansas    42756.166667
# 1        Kentucky    42702.666667
# 0   West Virginia    41960.500000

# %%
df_capita
# Out:
#                    State         Pop  n_killed  Avg_Death_Rate  \
# 0          West Virginia   1778070.0       335       18.840653
# 1               Kentucky   4499692.0      1066       23.690510
# 2               Arkansas   3038999.0       773       25.436007
# 3            Mississippi   2989260.0      1176       39.340840
# 4                Alabama   4908621.0      1880       38.299962
# 5             New Mexico   2096640.0       495       23.609203
# 6              Louisiana   4645184.0      2179       46.908798
# 7         South Carolina   5210095.0      1610       30.901548
# 8              Tennessee   6897576.0      1824       26.444073
# 9               Oklahoma   3954821.0       941       23.793744
# 10        North Carolina  10611862.0      2225       20.967103
# 11                 Idaho   1826156.0       166        9.090132
# 12               Montana   1086759.0       154       14.170575
# 13               Florida  21992985.0      3909       17.773849
# ...

# %%
df_capita[['State','Avg_per_capita']].sort_values('Avg_per_capita',ascending=False).head(10)
# Out:
#             State  Avg_per_capita
# 50       Maryland    74156.000000
# 49     New Jersey    73021.500000
# 48    Connecticut    71775.666667
# 47         Alaska    71080.500000
# 46         Hawaii    69656.500000
# 45  Massachusetts    68937.833333
# 44  New Hampshire    67797.833333
# 43       Virginia    65071.833333
# 42     California    64792.166667
# 41     Washington    63794.333333

# %%
df_capita[['State','Avg_Un_Emp']].sort_values('Avg_Un_Emp',ascending=False).head(10)
# Out:
#                    State  Avg_Un_Emp
# 20  District of Columbia    6.850000
# 47                Alaska    6.783333
# 22                Nevada    6.550000
# 3            Mississippi    6.350000
# 5             New Mexico    6.250000
# 42            California    6.200000
# 35              Illinois    6.183333
# 33          Rhode Island    6.100000
# 0          West Virginia    6.100000
# 17               Arizona    5.933333

# %%
df_capita[['State','Avg_Un_Emp']].sort_values('Avg_Un_Emp',ascending=False).tail(10)
# Out:
#             State  Avg_Un_Emp
# 11          Idaho    4.150000
# 32      Minnesota    3.850000
# 25           Iowa    3.666667
# 38           Utah    3.616667
# 44  New Hampshire    3.500000
# 46         Hawaii    3.466667
# 30        Vermont    3.416667
# 21   South Dakota    3.266667
# 28       Nebraska    3.166667
# 34   North Dakota    2.800000

# %%
df_capita.Avg_per_capita.mean()
# Out:
# 55265.91503267975

# %%
df_capita.Avg_Un_Emp.mean()
# Out:
# 5.039542483660131

# %%
#Risk score calculation involving Population, Per-Capita income and Unemployment rate
risk_harmless= .05*df_state_all['harmless_incident']
risk_fatal= .10*df_state_all['fatal_incident']
risk_Death_Rate= .25*df_state_all['Death_Rate']
risk_gun= .05*df_state_all['Guns_involved']
risk_injured= .05*df_state_all['n_injured']
risk_emp= .25*df_state_all['Avg_Un_Emp']
risk_capita= .25*df_state_all['Avg_per_capita']

risk_score=(risk_harmless+risk_fatal+risk_Death_Rate+risk_injured+risk_gun-risk_capita+risk_emp)/7
df_state_all['risk_score']=risk_score
df_state_all['risk_score']=round((df_state_all['risk_score']/max(df_state_all['risk_score']))*100)
df_state_all.sort_values('risk_score',ascending=False,inplace=True)

rank=list(range(1,52))
df_state_all['Risk_Rank']=rank


df_state_all['Rank_Change']=-(df_state_all['Risk_Rank']-df_state_all['Previous_Rank'])

# %%
df_state_all
# Out:
#                    State  harmless_incident  fatal_incident  n_killed_x  \
# 23  District of Columbia          25.658683       10.936346    8.252427
# 50              Illinois          60.089820      100.000000   61.290903
# 41             Louisiana          42.619760       38.812583   39.176555
# 28           Mississippi          16.931138       18.224782   21.143474
# 48               Florida         100.000000       61.652636   70.280475
# 33               Alabama          22.769461       29.168513   33.800791
# 49            California          94.835329       73.630188  100.000000
# 38        South Carolina          46.676647       28.215921   28.946422
# 46                  Ohio          53.203593       49.401861   45.091694
# 42               Georgia          57.050898       37.763994   44.156778
# 40             Tennessee          38.113772       37.512923   32.793959
# 39              Missouri          33.053892       32.661350   38.403452
# ...

# %%
# Bar chart to show which state is safer and dangerous based on involving Population, Per-Capita income and Unemployment rate
df_state_all.sort_values('risk_score', inplace=True,ascending=True)

likeability_scores = np.array(df_state_all.risk_score)
 
data_normalizer = mp.colors.Normalize()
color_map = mp.colors.LinearSegmentedColormap(
    "my_map",
    {
        "red": [(0, 1.0, 1.0),
                (1.0, .5, .5)],
        "green": [(0, 0.5, 0.5),
                  (1.0, 0, 0)],
        "blue": [(0, 0.50, 0.5),
                 (1.0, 0, 0)]
    }
)


plt.figure(figsize=(14,10), dpi= 80)
plt.barh(df_state_all.State, df_state_all.risk_score, align='center',color=color_map(data_normalizer(likeability_scores)))


plt.ylabel('State', fontsize = 12, weight = 'bold')
plt.xlabel('Risk Score', fontsize = 12, weight = 'bold')
plt.title('Which state is safer based on prediction score involving Population, Unemployment and Per-capita?', fontdict={'size':12},weight = 'bold')
plt.savefig("Risk_Rank_state_7.png",dpi='figure',quality=100) 
plt.show()

# %%
# Safety ranking of USA state affect based on Risk score generated
# Prepare Data

df_state_all['colors'] = ['red' if x < 0 else 'green' for x in df_state_all['Rank_Change']]
df_state_all.sort_values('Rank_Change', inplace=True)
df_state_all.reset_index(inplace=True)
# Draw plot
plt.figure(figsize=(14,10), dpi= 80)
plt.hlines(y=df_state_all.State, xmin=0, xmax=df_state_all.Rank_Change, color=df_state_all['colors'], alpha=0.7, linewidth=5)

# Decorations
plt.gca().set(ylabel='State', xlabel='Change in Rank')
plt.yticks(df_state_all.State, fontsize=10)
plt.ylabel('State', fontsize = 12, weight = 'bold')
plt.xlabel('Change in rank', fontsize = 12, weight = 'bold')
plt.title('Change in Rank after Risk Score prediction', fontsize = 12, weight = 'bold')
plt.grid(linestyle='--', alpha=0.5)
plt.savefig("Risk_Rank_change_7.png") 
plt.show()
